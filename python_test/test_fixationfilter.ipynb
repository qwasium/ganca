# %% [markdown]
# # `ganca.fixationfilter`

# %% [markdown]
# Prepare and select `venv` before running the script
#
# ```bash
# # Linux
# source ../venv/bin/activate # example; from this file's directory
# pip install ipykernel       # to run jupyter notebook
# ```

# %%
# !pip install pandas numpy

# %%
import os
import math
import pandas as pd
import ganca
from ganca.fixationfilter import pyFixationFilter

from py_test_func import pyTestFunc

# check current working directory
os.getcwd()
# Out:
# /tmp/ipykernel_124010/2737184208.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# '/home/bluqueen/Documents/dev/ganca/build/python/python_test'

# %%
dir(pyFixationFilter)
# Out:
# ['BoolVector',
#  'BoolVectorVector',
#  'DoubleVector',
#  'IVTFilter',
#  'SwigPyIterator',
#  '_SwigNonDynamicMeta',
#  '__builtin__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_pyFixationFilter',
#  '_swig_add_metaclass',
#  '_swig_python_version_info',
#  '_swig_repr',
#  '_swig_setattr_nondynamic_class_variable',
#  '_swig_setattr_nondynamic_instance_variable']

# %%
aka_timeseries = pd.read_csv('../../test_data/aka_timeseries.csv')
aka_timeseries['validity_gaze_left'] = aka_timeseries['validity_gaze_left'].astype('bool')
aka_timeseries['validity_gaze_right'] = aka_timeseries['validity_gaze_right'].astype('bool')
aka_timeseries
# Out:
#       eyetracker_timestamp  system_timestamp  validity_gaze_left  \
# 0               3600075022        1474112563                True
# 1               3600075857        1474113398                True
# 2               3600076691        1474114232                True
# 3               3600077522        1474115063                True
# 4               3600078357        1474115898                True
# ...                    ...               ...                 ...
# 5995            3605070846        1479108816                True
# 5996            3605071680        1479109650                True
# 5997            3605072511        1479110481                True
# 5998            3605073346        1479111316                True
# 5999            3605074180        1479112150                True
#
#       validity_gaze_right  gaze_point_adcs_left_x  gaze_point_adcs_left_y  \
# 0                    True                0.493344                0.474870
# ...

# %%
aka_left = pyFixationFilter.IVTFilter(
	timestamp=aka_timeseries['eyetracker_timestamp'].to_list(),
	validityIn=aka_timeseries['validity_gaze_left'].to_list(),
	gazeX=aka_timeseries['left_gaze_in_pixel_x'].to_list(),
	gazeY=aka_timeseries['left_gaze_in_pixel_y'].to_list(),
	winX=1920,
	winY=1080,
	# dist=0,
	velocityThreshold=5,
)
print(aka_left[0])
print(aka_left[1])
# Out:
# (False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, 
# ...
