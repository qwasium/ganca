# %% [markdown]
# # `ganca.heatmap`

# %% [markdown]
# Prepare and select `venv` before running the script
#
# ```bash
# # Linux
# source ../venv/bin/activate # example; from this file's directory
# pip install ipykernel       # to run jupyter notebook
# ```

# %% [markdown]
# Install python libraries if not installed.

# %%
# !pip install pandas
# !pip3 install pandas
# Out:
# ...
#   Using cached pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# ...
#   Using cached numpy-1.26.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# ...

# %%
import os
import pandas as pd
from ganca.heatmap import pyHeatmap

from py_test_func import pyTestFunc

# check current working directory
os.getcwd()
# Out:
# '/home/bluqueen/Documents/dev/ganca/build/python/python_test'

# %%
dir(pyHeatmap)
# Out:
# ['DoubleVector',
#  'DoubleVectorVector',
#  'SwigPyIterator',
#  '_SwigNonDynamicMeta',
#  '__builtin__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_pyHeatmap',
#  '_swig_add_metaclass',
#  '_swig_python_version_info',
#  '_swig_repr',
#  '_swig_setattr_nondynamic_class_variable',
#  '_swig_setattr_nondynamic_instance_variable',
#  'heatmapGauss']

# %% [markdown]
# Python implementation of `ganca.heatmap`

# %%
fix_x = [500, 680, 600, 499]
fix_y = [855, 691, 754, 855]
fix_dur = [0.3, 0.1, 0.2, 0.3]
win_x = 1920
win_y = 1080
heat_map = pyHeatmap.heatmapGauss(fixX=fix_x, fixY=fix_y, fixDuration=fix_dur, winX=win_x, winY=win_y, sigma_factor=1)

# %%
print(type(heat_map))
print(type(heat_map[0]))
print(len(heat_map))
print(len(heat_map[0]))
# print(heat_map)
# Out:
# <class 'tuple'>
# <class 'tuple'>
# 1920
# 1080

# %%
heat_map_python = pyTestFunc.heatmap_gauss(fix_x, fix_y, fix_dur, win_x, win_y, sigma_factor=1)
pyTestFunc.test_matrix(heat_map, heat_map_python)
# Out:
# True

# %%
# %%timeit
heat_map = pyHeatmap.heatmapGauss(fixX=fix_x, fixY=fix_y, fixDuration=fix_dur, winX=win_x, winY=win_y, sigma_factor=1)
# Out:
# 131 ms ± 5.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
heat_map_python = pyTestFunc.heatmap_gauss(fix_x, fix_y, fix_dur, win_x, win_y, sigma_factor=1)
# Out:
# 7.12 s ± 164 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Read test data.

# %%
aka_path = '../../test_data/aka_fixation.csv'
midori_path = '../../test_data/midori_fixation.csv'

aka_df = pd.read_csv(aka_path)
midori_df = pd.read_csv(midori_path)

# %%
aka_df
# Out:
#     FixStart    FixEnd   FixDur      XPos     YPos  FlankedByDataLoss  \
# 0    316.694   705.059  389.199   957.300  530.915                  0
# 1    736.730  1147.598  411.702   626.153  347.468                  0
# 2   1155.933  1396.785  241.686   661.517  345.178                  0
# 3   1424.288  1585.135  161.681   445.603  394.127                  0
# 4   1597.637  1756.815  160.013   346.835  390.472                  0
# 5   1781.820  2001.833  220.844   637.970  355.445                  0
# 6   2010.166  2230.186  220.851   599.695  357.990                  0
# 7   2277.690  2448.537  171.681  1243.332  560.847                  0
# 8   2465.206  3350.281  885.909  1215.580  656.350                  0
# 9   3374.448  3682.809  309.192  1278.965  537.635                  0
# 10  3718.645  3927.829  210.018  1373.293  186.582                  0
# 11  3939.497  4129.513  190.850  1390.800   82.090                  0
# ...

# %%
aka_fix_x = aka_df['XPos'].tolist()
aka_fix_y = aka_df['YPos'].tolist()
aka_fix_dur = aka_df['FixDur'].tolist()
aka_heatmap = pyHeatmap.heatmapGauss(
	fixX=aka_fix_x,
	fixY=aka_fix_y,
	fixDuration=aka_fix_dur,
	winX=1920,
	winY=1080,
	sigma_factor=1
)

# %%
print(type(aka_heatmap))
print(type(aka_heatmap[0]))
print(len(aka_heatmap))
print(len(aka_heatmap[0]))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# 1920
# 1080

# %%
pyTestFunc.test_matrix(
	aka_heatmap,
	pyTestFunc.heatmap_gauss(
		aka_fix_x,
		aka_fix_y,
		aka_fix_dur,
		1920,
		1080,
		sigma_factor=1
	)
)
# Out:
# True

# %%
# %%timeit
aka_heatmap = pyHeatmap.heatmapGauss(
	fixX=aka_fix_x,
	fixY=aka_fix_y,
	fixDuration=aka_fix_dur,
	winX=1920,
	winY=1080,
	sigma_factor=1
)
# Out:
# 473 ms ± 40.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
aka_heatmap_python = pyHeatmap.heatmap_gauss(
	fix_x=aka_fix_x,
	fix_y=aka_fix_y,
	fix_dur=aka_fix_dur,
	win_x=1920,
	win_y=1080,
	sigma_factor=1
)
# Out:
# 20.7 s ± 730 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
midori_df
# Out:
#     FixStart    FixEnd   FixDur      XPos     YPos  FlankedByDataLoss  \
# 0   1685.968  1906.821  221.684   550.112  420.825                  0
# 1   1928.489  2150.172  222.517   308.110  407.755                  0
# 2   2158.507  2413.530  255.857   245.635  425.130                  0
# 3   2436.863  2648.549  212.520   436.565  451.075                  0
# 4   2658.550  2878.568  220.852   555.615  452.620                  0
# 5   2886.902  3152.759  266.691   505.190  473.283                  0
# 6   3162.760  3560.294  398.368   588.678  481.810                  0
# 7   3582.796  3743.643  161.681   791.880  476.465                  0
# 8   3786.979  3923.658  137.513  1452.620  512.805                  0
# 9   3950.327  4134.504  185.011  1131.818  600.825                  0
# 10  4142.839  4318.687  176.679  1148.230  631.178                  0
# 11  4342.020  4592.041  250.855  1355.490  530.940                  0
# ...

# %%
midori_fix_x = midori_df['XPos'].tolist()
midori_fix_y = midori_df['YPos'].tolist()
midori_fix_dur = midori_df['FixDur'].tolist()
midori_heatmap = pyHeatmap.heatmapGauss(
	fixX=midori_fix_x,
	fixY=midori_fix_y,
	fixDuration=midori_fix_dur,
	winX=1920,
	winY=1080,
	sigma_factor=1
)

# %%
print(type(midori_heatmap))
print(type(midori_heatmap[0]))
print(len(midori_heatmap))
print(len(midori_heatmap[0]))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# 1920
# 1080

# %%
pyTestFunc.test_matrix(
	midori_heatmap,
	pyTestFunc.heatmap_gauss(
		midori_fix_x,
		midori_fix_y,
		midori_fix_dur,
		1920,
		1080,
		sigma_factor=1
	)
)
# Out:
# True

# %%
# %%timeit
midori_heatmap = pyHeatmap.heatmapGauss(
	fixX=midori_fix_x,
	fixY=midori_fix_y,
	fixDuration=midori_fix_dur,
	winX=1920,
	winY=1080,
	sigma_factor=1
)
# Out:
# 485 ms ± 65.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
midori_heatmap_python = pyTestFunc.heatmap_gauss(
	fix_x=midori_fix_x,
	fix_y=midori_fix_y,
	fix_dur=midori_fix_dur,
	win_x=1920,
	win_y=1080,
	sigma_factor=1
)
# Out:
# 21.1 s ± 391 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
